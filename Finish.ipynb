# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'fin.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-finish.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-finish.pkl
# [go] => [mene]
# [hi] => [moro]
# [hi] => [terve]
# [run] => [juokse]
# [run] => [juoskaa]
# [run] => [juokse]
# [who] => [kuka]
# [wow] => [mahtavaa]
# [wow] => [siistia]
# [wow] => [vau]
# [fire] => [tulta]
# [help] => [apua]
# [help] => [auttakaa]
# [help] => [auta]
# [hide] => [piiloon]
# [hide] => [piiloudu]
# [hide] => [piiloutukaa]
# [hide] => [mene piiloon]
# [hide] => [menkaa piiloon]
# [hide] => [talja]
# [hide] => [vuota]
# [hide] => [nahka]
# [hide] => [piilota]
# [hide] => [piilottakaa]
# [hide] => [jemmaa]
# [hide] => [jemmatkaa]
# [hide] => [katke]
# [hide] => [katkekaa]
# [hide] => [katkeydy]
# [hide] => [katkeytykaa]
# [hide] => [piilottele]
# [hide] => [piilotelkaa]
# [jump] => [hyppaa]
# [jump] => [hypatkaa]
# [jump] => [hyppaa]
# [jump] => [hypatkaa]
# [stay] => [paikka]
# [stay] => [pysy]
# [stay] => [pysykaa]
# [stay] => [jaa]
# [stay] => [jaakaa]
# [stop] => [lopeta]
# [stop] => [seis]
# [stop] => [pysahdy]
# [wait] => [odota]
# [wait] => [odottakaa]
# [wait] => [odota]
# [begin] => [aloita]
# [begin] => [aloittakaa]
# [begin] => [ala]
# [begin] => [alkakaa]
# [do it] => [tee se]
# [do it] => [tehkaa se]
# [hello] => [haloo]
# [hello] => [hei]
# [hello] => [moi]
# [hello] => [terve]
# [hello] => [heippa]
# [hello] => [moikka]
# [hello] => [moro]
# [hurry] => [kiiruhda]
# [hurry] => [pida kiiretta]
# [hurry] => [pitakaa kiiretta]
# [hurry] => [kiiruhtakaa]
# [hurry] => [vauhtia]
# [i see] => [ymmarran]
# [i see] => [naen]
# [i see] => [mina naen]
# [i see] => [mina ymmarran]
# [i try] => [yritan]
# [i won] => [ma voitin]
# [oh no] => [voi ei]
# [relax] => [ota rennosti]
# [relax] => [rentoudu]
# [shoot] => [ammu]
# [shoot] => [ampukaa]
# [shoot] => [laukaise]
# [shoot] => [laukaiskaa]
# [shoot] => [anna tulla]
# [shoot] => [antakaa tulla]
# [smile] => [sanokaa muikku]
# [smile] => [hymyile]
# [smile] => [hymya]
# [smile] => [hymyile]
# [smile] => [hymyilkaa]
# [attack] => [hyokkaa]
# [attack] => [hyokatkaa]
# [cheers] => [kippis]
# [cheers] => [kiitos]
# [cheers] => [kiitti]
# [cheers] => [holkynkolkyn]
# [freeze] => [seis]
# [freeze] => [liikkumatta]
# [get up] => [nouse ylos]
# [go now] => [mene nyt]
# [go now] => [menkaa nyt]
# [got it] => [tajusin]
# [got it] => [selva]
# [got it] => [ymmarsitko]
# [got it] => [tajusitko]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-finish.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-finish-both.pkl')
save_clean_data(train, 'english-finish-train.pkl')
save_clean_data(test, 'english-finish-test.pkl')
# Out:
# Saved: english-finish-both.pkl
# Saved: english-finish-train.pkl
# Saved: english-finish-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-finish-both.pkl')
train = load_clean_sentences('english-finish-train.pkl')
test = load_clean_sentences('english-finish-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Finish Vocabulary Size: %d' % ger_vocab_size)
print('Finish Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2386
# English Max Length: 5
# Finish Vocabulary Size: 5517
# Finish Max Length: 8
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 8, 256)            1412352
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 2386)           613202
# =================================================================
# Total params: 3,076,178
# Trainable params: 3,076,178
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 34s - loss: 4.5619 - val_loss: 3.6595
#
# Epoch 00001: val_loss improved from inf to 3.65954, saving model to model.h5
# Epoch 2/100
# 141/141 - 27s - loss: 3.5729 - val_loss: 3.4511
#
# Epoch 00002: val_loss improved from 3.65954 to 3.45112, saving model to model.h5
# Epoch 3/100
# 141/141 - 28s - loss: 3.4189 - val_loss: 3.3277
#
# Epoch 00003: val_loss improved from 3.45112 to 3.32771, saving model to model.h5
# Epoch 4/100
# 141/141 - 27s - loss: 3.2883 - val_loss: 3.1953
#
# Epoch 00004: val_loss improved from 3.32771 to 3.19529, saving model to model.h5
# Epoch 5/100
# 141/141 - 27s - loss: 3.1242 - val_loss: 3.0234
#
# Epoch 00005: val_loss improved from 3.19529 to 3.02340, saving model to model.h5
# Epoch 6/100
# 141/141 - 31s - loss: 2.9612 - val_loss: 2.8728
#
# Epoch 00006: val_loss improved from 3.02340 to 2.87279, saving model to model.h5
# Epoch 7/100
# 141/141 - 34s - loss: 2.8120 - val_loss: 2.7273
#
# Epoch 00007: val_loss improved from 2.87279 to 2.72727, saving model to model.h5
# Epoch 8/100
# 141/141 - 27s - loss: 2.6692 - val_loss: 2.5966
#
# Epoch 00008: val_loss improved from 2.72727 to 2.59663, saving model to model.h5
# Epoch 9/100
# 141/141 - 27s - loss: 2.5278 - val_loss: 2.4622
#
# Epoch 00009: val_loss improved from 2.59663 to 2.46225, saving model to model.h5
# Epoch 10/100
# 141/141 - 28s - loss: 2.3905 - val_loss: 2.3201
#
# Epoch 00010: val_loss improved from 2.46225 to 2.32010, saving model to model.h5
# Epoch 11/100
# 141/141 - 27s - loss: 2.2525 - val_loss: 2.1913
#
# Epoch 00011: val_loss improved from 2.32010 to 2.19134, saving model to model.h5
# Epoch 12/100
# 141/141 - 27s - loss: 2.1139 - val_loss: 2.0682
#
# Epoch 00012: val_loss improved from 2.19134 to 2.06819, saving model to model.h5
# Epoch 13/100
# 141/141 - 27s - loss: 1.9848 - val_loss: 1.9532
#
# Epoch 00013: val_loss improved from 2.06819 to 1.95325, saving model to model.h5
# Epoch 14/100
# 141/141 - 28s - loss: 1.8612 - val_loss: 1.8298
#
# Epoch 00014: val_loss improved from 1.95325 to 1.82981, saving model to model.h5
# Epoch 15/100
# 141/141 - 27s - loss: 1.7451 - val_loss: 1.7369
#
# Epoch 00015: val_loss improved from 1.82981 to 1.73688, saving model to model.h5
# Epoch 16/100
# 141/141 - 27s - loss: 1.6339 - val_loss: 1.6345
#
# Epoch 00016: val_loss improved from 1.73688 to 1.63447, saving model to model.h5
# Epoch 17/100
# 141/141 - 27s - loss: 1.5315 - val_loss: 1.5323
#
# Epoch 00017: val_loss improved from 1.63447 to 1.53230, saving model to model.h5
# Epoch 18/100
# 141/141 - 27s - loss: 1.4318 - val_loss: 1.4455
#
# Epoch 00018: val_loss improved from 1.53230 to 1.44553, saving model to model.h5
# Epoch 19/100
# 141/141 - 27s - loss: 1.3403 - val_loss: 1.3675
#
# Epoch 00019: val_loss improved from 1.44553 to 1.36755, saving model to model.h5
# Epoch 20/100
# 141/141 - 27s - loss: 1.2539 - val_loss: 1.2912
#
# Epoch 00020: val_loss improved from 1.36755 to 1.29116, saving model to model.h5
# Epoch 21/100
# 141/141 - 28s - loss: 1.1707 - val_loss: 1.2211
#
# Epoch 00021: val_loss improved from 1.29116 to 1.22106, saving model to model.h5
# Epoch 22/100
# 141/141 - 27s - loss: 1.0917 - val_loss: 1.1560
#
# Epoch 00022: val_loss improved from 1.22106 to 1.15597, saving model to model.h5
# Epoch 23/100
# 141/141 - 27s - loss: 1.0235 - val_loss: 1.0941
#
# Epoch 00023: val_loss improved from 1.15597 to 1.09407, saving model to model.h5
# Epoch 24/100
# 141/141 - 27s - loss: 0.9541 - val_loss: 1.0339
#
# Epoch 00024: val_loss improved from 1.09407 to 1.03388, saving model to model.h5
# Epoch 25/100
# 141/141 - 27s - loss: 0.8847 - val_loss: 0.9742
#
# Epoch 00025: val_loss improved from 1.03388 to 0.97422, saving model to model.h5
# Epoch 26/100
# 141/141 - 28s - loss: 0.8218 - val_loss: 0.9249
#
# Epoch 00026: val_loss improved from 0.97422 to 0.92488, saving model to model.h5
# Epoch 27/100
# 141/141 - 28s - loss: 0.7697 - val_loss: 0.8819
#
# Epoch 00027: val_loss improved from 0.92488 to 0.88187, saving model to model.h5
# Epoch 28/100
# 141/141 - 27s - loss: 0.7156 - val_loss: 0.8297
#
# Epoch 00028: val_loss improved from 0.88187 to 0.82969, saving model to model.h5
# Epoch 29/100
# 141/141 - 27s - loss: 0.6626 - val_loss: 0.7926
#
# Epoch 00029: val_loss improved from 0.82969 to 0.79257, saving model to model.h5
# Epoch 30/100
# 141/141 - 27s - loss: 0.6162 - val_loss: 0.7574
#
# Epoch 00030: val_loss improved from 0.79257 to 0.75738, saving model to model.h5
# Epoch 31/100
# 141/141 - 27s - loss: 0.5739 - val_loss: 0.7177
#
# Epoch 00031: val_loss improved from 0.75738 to 0.71768, saving model to model.h5
# Epoch 32/100
# 141/141 - 28s - loss: 0.5356 - val_loss: 0.6873
#
# Epoch 00032: val_loss improved from 0.71768 to 0.68731, saving model to model.h5
# Epoch 33/100
# 141/141 - 27s - loss: 0.4971 - val_loss: 0.6569
#
# Epoch 00033: val_loss improved from 0.68731 to 0.65692, saving model to model.h5
# Epoch 34/100
# 141/141 - 28s - loss: 0.4639 - val_loss: 0.6286
#
# Epoch 00034: val_loss improved from 0.65692 to 0.62860, saving model to model.h5
# Epoch 35/100
# 141/141 - 28s - loss: 0.4304 - val_loss: 0.6073
#
# Epoch 00035: val_loss improved from 0.62860 to 0.60726, saving model to model.h5
# Epoch 36/100
# 141/141 - 28s - loss: 0.4031 - val_loss: 0.5828
#
# Epoch 00036: val_loss improved from 0.60726 to 0.58282, saving model to model.h5
# Epoch 37/100
# 141/141 - 28s - loss: 0.3765 - val_loss: 0.5615
#
# Epoch 00037: val_loss improved from 0.58282 to 0.56146, saving model to model.h5
# Epoch 38/100
# 141/141 - 27s - loss: 0.3519 - val_loss: 0.5445
#
# Epoch 00038: val_loss improved from 0.56146 to 0.54454, saving model to model.h5
# Epoch 39/100
# 141/141 - 27s - loss: 0.3308 - val_loss: 0.5288
#
# Epoch 00039: val_loss improved from 0.54454 to 0.52877, saving model to model.h5
# Epoch 40/100
# 141/141 - 27s - loss: 0.3105 - val_loss: 0.5147
#
# Epoch 00040: val_loss improved from 0.52877 to 0.51469, saving model to model.h5
# Epoch 41/100
# 141/141 - 27s - loss: 0.2898 - val_loss: 0.4971
#
# Epoch 00041: val_loss improved from 0.51469 to 0.49713, saving model to model.h5
# Epoch 42/100
# 141/141 - 28s - loss: 0.2717 - val_loss: 0.4835
#
# Epoch 00042: val_loss improved from 0.49713 to 0.48348, saving model to model.h5
# Epoch 43/100
# 141/141 - 28s - loss: 0.2599 - val_loss: 0.4799
#
# Epoch 00043: val_loss improved from 0.48348 to 0.47992, saving model to model.h5
# Epoch 44/100
# 141/141 - 28s - loss: 0.2457 - val_loss: 0.4662
#
# Epoch 00044: val_loss improved from 0.47992 to 0.46616, saving model to model.h5
# Epoch 45/100
# 141/141 - 28s - loss: 0.2330 - val_loss: 0.4547
#
# Epoch 00045: val_loss improved from 0.46616 to 0.45470, saving model to model.h5
# Epoch 46/100
# 141/141 - 28s - loss: 0.2219 - val_loss: 0.4493
#
# Epoch 00046: val_loss improved from 0.45470 to 0.44934, saving model to model.h5
# Epoch 47/100
# 141/141 - 28s - loss: 0.2113 - val_loss: 0.4418
#
# Epoch 00047: val_loss improved from 0.44934 to 0.44176, saving model to model.h5
# Epoch 48/100
# 141/141 - 28s - loss: 0.2009 - val_loss: 0.4351
#
# Epoch 00048: val_loss improved from 0.44176 to 0.43512, saving model to model.h5
# Epoch 49/100
# 141/141 - 28s - loss: 0.1927 - val_loss: 0.4292
#
# Epoch 00049: val_loss improved from 0.43512 to 0.42920, saving model to model.h5
# Epoch 50/100
# 141/141 - 28s - loss: 0.1854 - val_loss: 0.4285
#
# Epoch 00050: val_loss improved from 0.42920 to 0.42853, saving model to model.h5
# Epoch 51/100
# 141/141 - 28s - loss: 0.1801 - val_loss: 0.4234
#
# Epoch 00051: val_loss improved from 0.42853 to 0.42343, saving model to model.h5
# Epoch 52/100
# 141/141 - 28s - loss: 0.1740 - val_loss: 0.4163
#
# Epoch 00052: val_loss improved from 0.42343 to 0.41632, saving model to model.h5
# Epoch 53/100
# 141/141 - 28s - loss: 0.1667 - val_loss: 0.4124
#
# Epoch 00053: val_loss improved from 0.41632 to 0.41238, saving model to model.h5
# Epoch 54/100
# 141/141 - 28s - loss: 0.1616 - val_loss: 0.4106
#
# Epoch 00054: val_loss improved from 0.41238 to 0.41062, saving model to model.h5
# Epoch 55/100
# 141/141 - 27s - loss: 0.1586 - val_loss: 0.4069
#
# Epoch 00055: val_loss improved from 0.41062 to 0.40694, saving model to model.h5
# Epoch 56/100
# 141/141 - 27s - loss: 0.1536 - val_loss: 0.4058
#
# Epoch 00056: val_loss improved from 0.40694 to 0.40585, saving model to model.h5
# Epoch 57/100
# 141/141 - 27s - loss: 0.1502 - val_loss: 0.4043
#
# Epoch 00057: val_loss improved from 0.40585 to 0.40429, saving model to model.h5
# Epoch 58/100
# 141/141 - 27s - loss: 0.1470 - val_loss: 0.4016
#
# Epoch 00058: val_loss improved from 0.40429 to 0.40160, saving model to model.h5
# Epoch 59/100
# 141/141 - 27s - loss: 0.1434 - val_loss: 0.4023
#
# Epoch 00059: val_loss did not improve from 0.40160
# Epoch 60/100
# 141/141 - 28s - loss: 0.1404 - val_loss: 0.3993
#
# Epoch 00060: val_loss improved from 0.40160 to 0.39928, saving model to model.h5
# Epoch 61/100
# 141/141 - 27s - loss: 0.1373 - val_loss: 0.3976
#
# Epoch 00061: val_loss improved from 0.39928 to 0.39761, saving model to model.h5
# Epoch 62/100
# 141/141 - 27s - loss: 0.1351 - val_loss: 0.3957
#
# Epoch 00062: val_loss improved from 0.39761 to 0.39565, saving model to model.h5
# Epoch 63/100
# 141/141 - 27s - loss: 0.1321 - val_loss: 0.3992
#
# Epoch 00063: val_loss did not improve from 0.39565
# Epoch 64/100
# 141/141 - 27s - loss: 0.1314 - val_loss: 0.3950
#
# Epoch 00064: val_loss improved from 0.39565 to 0.39503, saving model to model.h5
# Epoch 65/100
# 141/141 - 27s - loss: 0.1291 - val_loss: 0.3978
#
# Epoch 00065: val_loss did not improve from 0.39503
# Epoch 66/100
# 141/141 - 28s - loss: 0.1281 - val_loss: 0.3955
#
# Epoch 00066: val_loss did not improve from 0.39503
# Epoch 67/100
# 141/141 - 28s - loss: 0.1255 - val_loss: 0.3953
#
# Epoch 00067: val_loss did not improve from 0.39503
# Epoch 68/100
# 141/141 - 28s - loss: 0.1249 - val_loss: 0.3939
#
# Epoch 00068: val_loss improved from 0.39503 to 0.39392, saving model to model.h5
# Epoch 69/100
# 141/141 - 28s - loss: 0.1234 - val_loss: 0.3925
#
# Epoch 00069: val_loss improved from 0.39392 to 0.39251, saving model to model.h5
# Epoch 70/100
# 141/141 - 27s - loss: 0.1219 - val_loss: 0.3930
#
# Epoch 00070: val_loss did not improve from 0.39251
# Epoch 71/100
# 141/141 - 28s - loss: 0.1211 - val_loss: 0.3942
#
# Epoch 00071: val_loss did not improve from 0.39251
# Epoch 72/100
# 141/141 - 28s - loss: 0.1213 - val_loss: 0.3950
#
# Epoch 00072: val_loss did not improve from 0.39251
# Epoch 73/100
# 141/141 - 27s - loss: 0.1198 - val_loss: 0.3950
#
# Epoch 00073: val_loss did not improve from 0.39251
# Epoch 74/100
# 141/141 - 27s - loss: 0.1192 - val_loss: 0.3933
#
# Epoch 00074: val_loss did not improve from 0.39251
# Epoch 75/100
# 141/141 - 28s - loss: 0.1168 - val_loss: 0.3960
#
# Epoch 00075: val_loss did not improve from 0.39251
# Epoch 76/100
# 141/141 - 28s - loss: 0.1180 - val_loss: 0.3940
#
# Epoch 00076: val_loss did not improve from 0.39251
# Epoch 77/100
# 141/141 - 28s - loss: 0.1174 - val_loss: 0.3933
#
# Epoch 00077: val_loss did not improve from 0.39251
# Epoch 78/100
# 141/141 - 28s - loss: 0.1154 - val_loss: 0.3955
#
# Epoch 00078: val_loss did not improve from 0.39251
# Epoch 79/100
# 141/141 - 28s - loss: 0.1159 - val_loss: 0.3926
#
# Epoch 00079: val_loss did not improve from 0.39251
# Epoch 80/100
# 141/141 - 27s - loss: 0.1150 - val_loss: 0.3951
#
# Epoch 00080: val_loss did not improve from 0.39251
# Epoch 81/100
# 141/141 - 27s - loss: 0.1154 - val_loss: 0.3956
#
# Epoch 00081: val_loss did not improve from 0.39251
# Epoch 82/100
# 141/141 - 27s - loss: 0.1127 - val_loss: 0.3944
#
# Epoch 00082: val_loss did not improve from 0.39251
# Epoch 83/100
# 141/141 - 28s - loss: 0.1113 - val_loss: 0.3931
#
# Epoch 00083: val_loss did not improve from 0.39251
# Epoch 84/100
# 141/141 - 27s - loss: 0.1108 - val_loss: 0.3932
#
# Epoch 00084: val_loss did not improve from 0.39251
# Epoch 85/100
# 141/141 - 27s - loss: 0.1093 - val_loss: 0.3923
#
# Epoch 00085: val_loss improved from 0.39251 to 0.39230, saving model to model.h5
# Epoch 86/100
# 141/141 - 27s - loss: 0.1083 - val_loss: 0.3928
#
# Epoch 00086: val_loss did not improve from 0.39230
# Epoch 87/100
# 141/141 - 27s - loss: 0.1080 - val_loss: 0.3967
#
# Epoch 00087: val_loss did not improve from 0.39230
# Epoch 88/100
# 141/141 - 28s - loss: 0.1073 - val_loss: 0.3980
#
# Epoch 00088: val_loss did not improve from 0.39230
# Epoch 89/100
# 141/141 - 27s - loss: 0.1087 - val_loss: 0.3969
#
# Epoch 00089: val_loss did not improve from 0.39230
# Epoch 90/100
# 141/141 - 28s - loss: 0.1081 - val_loss: 0.3936
#
# Epoch 00090: val_loss did not improve from 0.39230
# Epoch 91/100
# 141/141 - 27s - loss: 0.1069 - val_loss: 0.3958
#
# Epoch 00091: val_loss did not improve from 0.39230
# Epoch 92/100
# 141/141 - 27s - loss: 0.1061 - val_loss: 0.3956
#
# Epoch 00092: val_loss did not improve from 0.39230
# Epoch 93/100
# 141/141 - 27s - loss: 0.1059 - val_loss: 0.3956
#
# Epoch 00093: val_loss did not improve from 0.39230
# Epoch 94/100
# 141/141 - 28s - loss: 0.1061 - val_loss: 0.3969
#
# Epoch 00094: val_loss did not improve from 0.39230
# Epoch 95/100
# 141/141 - 28s - loss: 0.1076 - val_loss: 0.3970
#
# Epoch 00095: val_loss did not improve from 0.39230
# Epoch 96/100
# 141/141 - 27s - loss: 0.1057 - val_loss: 0.3974
#
# Epoch 00096: val_loss did not improve from 0.39230
# Epoch 97/100
# 141/141 - 27s - loss: 0.1061 - val_loss: 0.4004
#
# Epoch 00097: val_loss did not improve from 0.39230
# Epoch 98/100
# 141/141 - 27s - loss: 0.1064 - val_loss: 0.3998
#
# Epoch 00098: val_loss did not improve from 0.39230
# Epoch 99/100
# 141/141 - 28s - loss: 0.1064 - val_loss: 0.4015
#
# Epoch 00099: val_loss did not improve from 0.39230
# Epoch 100/100
# 141/141 - 27s - loss: 0.1062 - val_loss: 0.4030
#
# Epoch 00100: val_loss did not improve from 0.39230

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-finish-both.pkl')
train = load_clean_sentences('english-finish-train.pkl')
test = load_clean_sentences('english-finish-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[onko tom mukana suunnitelmassa], target=[is tom with us], predicted=[is tom with us]
# src=[olkaa hyva], target=[here you are], predicted=[here you are]
# src=[tom on opettaja], target=[tom is a teacher], predicted=[tom is a teacher]
# src=[anna tuo minulle], target=[give that to me], predicted=[give that to me]
# src=[tom sai tyopaikan], target=[tom got a job], predicted=[tom got a job]
# src=[tom teki sen], target=[tom did do it], predicted=[tom did do it]
# src=[tykkaan kakusta], target=[i like cake], predicted=[i like cake]
# src=[tulin juuri takaisin], target=[i just got back], predicted=[i just got back]
# src=[shamppanjaa kiitos], target=[champagne please], predicted=[champagne please]
# src=[ole ystavallinen], target=[be kind], predicted=[be kind]
# BLEU-1: 0.939178
# BLEU-2: 0.917343
# BLEU-3: 0.862896
# BLEU-4: 0.649548
# test
# src=[lippu kiitos], target=[ticket please], predicted=[ticket please]
# src=[pandat ovat sopoja], target=[pandas are cute], predicted=[pandas are cute]
# src=[pidan tuosta hameesta], target=[i like that skirt], predicted=[i like that skirt]
# src=[tartu tuomoon], target=[grab tom], predicted=[grab tom]
# src=[sen oli oltava sina], target=[it had to be you], predicted=[it had to be you]
# src=[mina pyysin anteeksi], target=[i apologized], predicted=[i apologized]
# src=[katkeytykaa], target=[hide], predicted=[hide]
# src=[suudelkaa tomia], target=[kiss tom], predicted=[kiss tom]
# src=[mina tarjoan], target=[its on me], predicted=[its my me]
# src=[keta sina suutelit], target=[who did you kiss], predicted=[who did you kiss]
# BLEU-1: 0.893149
# BLEU-2: 0.862533
# BLEU-3: 0.810271
# BLEU-4: 0.600799
